# %%
# Import libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline enables the drawing of matplotlib figures in the IPython environment

# %matplotlib inline 
matplotlib.rcParams['figure.figsize'] = 12,8 # Adjusts the configuration of the plot

# Read in the data

df = pd.read_csv(r'C:\Users\user\Desktop\Portfolio\Python Projects\Movies Project\movies.csv')

# %%
# Looking at the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Checking missing data - using loop 

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# For this project, I decided to drop the nulls and make double check.
df = df.dropna()

# %%
# Columns data type

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime       int64
# dtype: object

# %%
# Changing data typs from float64 to int64

df['votes'] = df['votes'].astype('int64') 
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['runtime'] = df['runtime'].astype('int64')

# %%
# Creating new column for extracting the current year from 'released' column

df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)

df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
# Ordering by 'gross' column

df = df.sort_values('gross', inplace=False, ascending=False)

# When inplace = False , which is the default, then "df" statement after isn't needed 
# because it would save the sort_values by itself

# %%
# Changing the pandas option to display all the dataset

# pd.set_option('display.max_rows', None)

pd.set_option('display.max_rows', 20)

# %%
# Drop any duplicates

# df['company'].drop_duplicates().sort_values(ascending=False)

# In other words it's showing the distinct values

df.drop_duplicates()
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes             director  \
# ...

# %%
df
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes             director  \
# ...

# %%
# Correlation 

# Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earning')

plt.xlabel('Budget')

plt.ylabel('Gross Earning')

plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# Plot Budget vs Gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color': 'red'}, line_kws={'color': 'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# removing columns

df_updated = df.drop(['year'], axis = 1)

df_updated
# Out:
#                                             name     rating   genre  \
# 5445                                      Avatar      PG-13  Action
# 7445                           Avengers: Endgame      PG-13  Action
# 3045                                     Titanic      PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action
# 7244                      Avengers: Infinity War      PG-13  Action
# ...                                          ...        ...     ...
# 5640                                 Tanner Hall          R   Drama
# 2434                  Philadelphia Experiment II      PG-13  Action
# 3681                                Ginger Snaps  Not Rated   Drama
# 272                                     Parasite          R  Horror
# 3203                                  Trojan War      PG-13  Comedy
#
#                                released  score    votes             director  \
# ...

# %%
# Correlation by 'corr' function (working just on numeric fields)

df_updated.corr()

# type of correlation (pearson(default), kandall, spearman)

#df.corr(method= '   ')
# Out:
#                 score     votes    budget     gross   runtime  yearcorrect
# score        1.000000  0.474256  0.072001  0.222556  0.414068     0.061923
# votes        0.474256  1.000000  0.439675  0.614751  0.352303     0.203098
# budget       0.072001  0.439675  1.000000  0.740247  0.318695     0.320312
# gross        0.222556  0.614751  0.740247  1.000000  0.275796     0.268721
# runtime      0.414068  0.352303  0.318695  0.275796  1.000000     0.075294
# yearcorrect  0.061923  0.203098  0.320312  0.268721  0.075294     1.000000

# %%
correlation_matrix = df_updated.corr(method= 'pearson')

sns.heatmap(correlation_matrix, annot=True)

# "annot=True" is showing the details (numbers) 

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
corr_pairs = correlation_matrix.unstack()

corr_pairs
# Out:
# score        score          1.000000
#              votes          0.474256
#              budget         0.072001
#              gross          0.222556
#              runtime        0.414068
#              yearcorrect    0.061923
# votes        score          0.474256
#              votes          1.000000
#              budget         0.439675
#              gross          0.614751
#              runtime        0.352303
#              yearcorrect    0.203098
# budget       score          0.072001
#              votes          0.439675
#              budget         1.000000
#              gross          0.740247
#              runtime        0.318695
#              yearcorrect    0.320312
# gross        score          0.222556
#              votes          0.614751
#              budget         0.740247
#              gross          1.000000
#              runtime        0.275796
#              yearcorrect    0.268721
# runtime      score          0.414068
# ...

# %%
sorted_pairs = corr_pairs.sort_values(ascending = False)

sorted_pairs
# Out:
# score        score          1.000000
# votes        votes          1.000000
# runtime      runtime        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# yearcorrect  yearcorrect    1.000000
# gross        budget         0.740247
# budget       gross          0.740247
# votes        gross          0.614751
# gross        votes          0.614751
# votes        score          0.474256
# score        votes          0.474256
# votes        budget         0.439675
# budget       votes          0.439675
# runtime      score          0.414068
# score        runtime        0.414068
# runtime      votes          0.352303
# votes        runtime        0.352303
# budget       yearcorrect    0.320312
# yearcorrect  budget         0.320312
# runtime      budget         0.318695
# budget       runtime        0.318695
# runtime      gross          0.275796
# gross        runtime        0.275796
# yearcorrect  gross          0.268721
# ...

# %%
sorted_pairs[(sorted_pairs) > 0.5]
# Out:
# score        score          1.000000
# votes        votes          1.000000
# runtime      runtime        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# yearcorrect  yearcorrect    1.000000
# gross        budget         0.740247
# budget       gross          0.740247
# votes        gross          0.614751
# gross        votes          0.614751
# dtype: float64

# %%
# gross vs budget, and votes vs gross have the highest correlation
